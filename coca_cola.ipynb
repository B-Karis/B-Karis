# %% [markdown]
# <a href="https://colab.research.google.com/github/B-Karis/B-Karis/blob/main/coca_cola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#to read the pdf and convert the table in the pdf to csv
# !pip install tabula-py
# Out:
# Collecting tabula-py
#   Downloading tabula_py-2.3.0-py3-none-any.whl (12.0 MB)
#      |████████████████████████████████| 12.0 MB 7.7 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from tabula-py) (1.21.5)
# Collecting distro
#   Downloading distro-1.7.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.7/dist-packages (from tabula-py) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->tabula-py) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25.3->tabula-py) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.25.3->tabula-py) (1.15.0)
# Installing collected packages: distro, tabula-py
# Successfully installed distro-1.7.0 tabula-py-2.3.0

# %%
from tabula import read_pdf
from tabula import convert_into
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import numpy as np
colour = sns.color_palette()

# %%
# !pip install pdftables
# Out:
# Collecting pdftables
#   Downloading pdftables-0.0.4.tar.gz (19 kB)
# Collecting pdfminer==20110515
#   Downloading pdfminer-20110515.tar.gz (4.1 MB)
#      |████████████████████████████████| 4.1 MB 25.4 MB/s
# WARNING: Discarding https://files.pythonhosted.org/packages/ce/f8/512bcd1a116d0332ab9fab84c3771d4699216db1086e120d581535665c31/pdfminer-20110515.tar.gz#sha256=114bddcc196b1ce893ab78815e3682ef7c56e9f5990e469dcc64cba93821b8ef (from https://pypi.org/simple/pdfminer/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Collecting pdftables
#   Downloading pdftables-0.0.3.tar.gz (19 kB)
# Collecting pdfminer>=20110515
#   Downloading pdfminer-20191125.tar.gz (4.2 MB)
#      |████████████████████████████████| 4.2 MB 30.1 MB/s
# Requirement already satisfied: numpy>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from pdftables) (1.21.5)
# Collecting pycryptodome
#   Downloading pycryptodome-3.14.1-cp35-abi3-manylinux2010_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 8.9 MB/s
# Building wheels for collected packages: pdftables, pdfminer
#   Building wheel for pdftables (setup.py) ... done
#   Created wheel for pdftables: filename=pdftables-0.0.3-py3-none-any.whl size=18108 sha256=892efce3750b0ecabd3a7d17d2ca7ef5afa1d17c9aa76dd7b16426d552774a8b
#   Stored in directory: /root/.cache/pip/wheels/cb/2d/51/898c17d9f15f7fb51d88d4a8e6ae917bd0c5ab72cd3318cbed
#   Building wheel for pdfminer (setup.py) ... done
#   Created wheel for pdfminer: filename=pdfminer-20191125-py3-none-any.whl size=6140092 sha256=6b05991a7dd6c8e3d13a2f6f3f30b758a0be75b95c1d930068c71ecd26f71f35
#   Stored in directory: /root/.cache/pip/wheels/e3/5e/f4/d210b46e9e4a28229ea070ed5b3efa92c3c29d1a7918dd4b97
# Successfully built pdftables pdfminer
# Installing collected packages: pycryptodome, pdfminer, pdftables
# Successfully installed pdfminer-20191125 pdftables-0.0.3 pycryptodome-3.14.1

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f65085cd-9b19-42fd-885f-baac65a8fdb3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f65085cd-9b19-42fd-885f-baac65a8fdb3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2022.pdf to 2022.pdf

# %%
pg = read_pdf('/2022.pdf', pages =11)
csv=convert_into('/2022.pdf', '/main.csv', output_format ='csv', pages=11)

# %%
pg = read_pdf('/content/2010.pdf', pages =7)
csv=convert_into('/content/2010.pdf', '/main_a.csv', output_format ='csv', pages=7)

pg = read_pdf('/content/2012.pdf', pages =18)
csv=convert_into('/content/2012.pdf', '/main_b.csv', output_format ='csv', pages=18)

pg = read_pdf('/content/2014.pdf', pages =13)
csv=convert_into('/content/2014.pdf', '/main_c.csv', output_format ='csv', pages=13)

pg = read_pdf('/content/2016.pdf', pages =12)
csv=convert_into('/content/2016.pdf', '/main_d.csv', output_format ='csv', pages=12)

pg = read_pdf('/content/2018.pdf', pages =10)
csv=convert_into('/content/2018.pdf', '/main_e.csv', output_format ='csv', pages=10)

pg = read_pdf('/content/2019.pdf', pages =10)
csv=convert_into('/content/2019.pdf', '/main_f.csv', output_format ='csv', pages=10)

# %%
df=pd.read_csv('/COCA_COLA.csv')
df
# Out:
#     YEAR Net Operating Revenues Cost of goods sold Gross Profit  \
# 0   2009                $30,990            $11,088      $19,902
# 1   2010                $35,119            $12,693      $22,426
# 2   2011                $46,542            $18,215      $28,327
# 3   2012                $48,017            $19,053      $28,964
# 4   2013                $46,854            $18,421      $28,433
# 5   2014                $45,998            $17,889      $28,109
# 6   2015                $44,294            $17,482      $26,812
# 7   2016                $41,863            $16,465      $25,398
# 8   2017                $35,410            $13,255      $22,155
# 9   2018                $34,300            $13,067      $21,233
# 10  2019                $37,266            $14,619      $22,647
#
#    Selling, general and administrative expenses Other operating charges  \
# 0                                       $11,358                    $313
# 1                                       $13,158                    $819
# 2                                       $17,422                    $732
# 3                                       $17,738                    $447
# 4                                       $17,310                    $895
# 5                                       $17,218                  $1,183
# 6                                       $16,427                  $1,657
# 7                                       $15,262                  $1,510
# 8                                       $12,654                  $1,902
# 9                                       $11,002                  $1,079
# 10                                      $12,103                    $458
#
#    Operating Income Interest income Interest expense  \
# 0            $8,231            $249             $355
# 1            $8,449            $317             $733
# 2           $10,173            $483             $417
# 3           $10,779            $471             $397
# 4           $10,228            $534             $463
# 5            $9,708            $594             $483
# 6            $8,728            $613             $856
# 7            $8,626            $642             $733
# 8            $7,599            $677             $841
# 9            $9,152            $689             $950
# 10          $10,086            $563             $946
#
#    Equity income (loss) — net Income Before Income Taxes Income taxes  \
# 0                        $781                     $8,946       $2,040
# 1                      $1,025                    $14,243       $2,384
# 2                        $690                    $11,458       $2,812
# 3                        $819                    $11,809       $2,723
# 4                        $602                    $11,477       $2,851
# 5                        $769                     $9,325       $2,201
# 6                        $489                     $9,605       $2,239
# 7                        $835                     $8,136       $1,586
# 8                      $1,071                     $6,742       $5,560
# 9                      $1,008                     $8,225       $1,749
# 10                     $1,049                    $10,786       $1,801
#
#    Consolidated Net Income  \
# 0                   $6,906
# 1                  $11,859
# 2                   $8,646
# 3                   $9,086
# 4                   $8,626
# 5                   $7,124
# 6                   $7,366
# 7                   $6,550
# 8                   $1,283
# 9                   $6,476
# 10                  $8,985
#
#    Less: Net income attributable to noncontrolling interests  \
# 0                                                 $82
# 1                                                 $50
# 2                                                 $62
# 3                                                 $67
# 4                                                 $42
# 5                                                 $26
# 6                                                 $15
# 7                                                 $23
# 8                                                 $35
# 9                                                 $42
# 10                                                $65
#
#    Net Income Attributable to Shareowners of The Coca-Cola Company  \
# 0                                              $6,824
# 1                                             $11,809
# 2                                              $8,584
# 3                                              $9,019
# 4                                              $8,584
# 5                                              $7,098
# 6                                              $7,351
# 7                                              $6,527
# 8                                              $1,248
# 9                                              $6,434
# 10                                             $8,920
#
#    Diluted Net Income Per Share 2,3 Average Shares Outstanding Diluted
# 0                                $3                             $2,329
# 1                                $5                             $2,333
# 2                                $2                             $4,646
# 3                                $2                             $4,584
# 4                                $2                             $4,509
# 5                                $2                             $4,450
# 6                                $2                             $4,405
# 7                                $1                             $4,367
# 8                                $0                             $4,324
# 9                                $2                             $4,299
# 10                               $2                             $4,314

# %%
df.head()
# Out:
#    YEAR Net Operating Revenues Cost of goods sold Gross Profit  \
# 0  2009                $30,990            $11,088      $19,902
# 1  2010                $35,119            $12,693      $22,426
# 2  2011                $46,542            $18,215      $28,327
# 3  2012                $48,017            $19,053      $28,964
# 4  2013                $46,854            $18,421      $28,433
#
#   Selling, general and administrative expenses Other operating charges  \
# 0                                      $11,358                    $313
# 1                                      $13,158                    $819
# 2                                      $17,422                    $732
# 3                                      $17,738                    $447
# 4                                      $17,310                    $895
#
#   Operating Income Interest income Interest expense  \
# 0           $8,231            $249             $355
# 1           $8,449            $317             $733
# 2          $10,173            $483             $417
# 3          $10,779            $471             $397
# 4          $10,228            $534             $463
#
#   Equity income (loss) — net Income Before Income Taxes Income taxes  \
# 0                       $781                     $8,946       $2,040
# 1                     $1,025                    $14,243       $2,384
# 2                       $690                    $11,458       $2,812
# 3                       $819                    $11,809       $2,723
# 4                       $602                    $11,477       $2,851
#
#   Consolidated Net Income  \
# 0                  $6,906
# 1                 $11,859
# 2                  $8,646
# 3                  $9,086
# 4                  $8,626
#
#   Less: Net income attributable to noncontrolling interests  \
# 0                                                $82
# 1                                                $50
# 2                                                $62
# 3                                                $67
# 4                                                $42
#
#   Net Income Attributable to Shareowners of The Coca-Cola Company  \
# 0                                             $6,824
# 1                                            $11,809
# 2                                             $8,584
# 3                                             $9,019
# 4                                             $8,584
#
#   Diluted Net Income Per Share 2,3 Average Shares Outstanding Diluted
# 0                               $3                             $2,329
# 1                               $5                             $2,333
# 2                               $2                             $4,646
# 3                               $2                             $4,584
# 4                               $2                             $4,509

# %%
df.dtypes
# Out:
# YEAR                                                                int64
# Net Operating Revenues                                             object
# Cost of goods sold                                                 object
# Gross Profit                                                       object
# Selling, general and administrative expenses                       object
# Other operating charges                                            object
# Operating Income                                                   object
# Interest income                                                    object
# Interest expense                                                   object
# Equity income (loss) — net                                         object
# Income Before Income Taxes                                         object
# Income taxes                                                       object
# Consolidated Net Income                                            object
# Less: Net income attributable to noncontrolling interests          object
# Net Income Attributable to Shareowners of The Coca-Cola Company    object
# Diluted Net Income Per Share 2,3                                   object
# Average Shares Outstanding Diluted                                 object
# dtype: object

# %%
df[df.columns[1:]] = df[df.columns[1:]].apply(lambda x: x.str[1:].str.split(',',).str.join('')).astype(np.int64)
df
# Out:
#     YEAR  Net Operating Revenues  Cost of goods sold  Gross Profit  \
# 0   2009                   30990               11088         19902
# 1   2010                   35119               12693         22426
# 2   2011                   46542               18215         28327
# 3   2012                   48017               19053         28964
# 4   2013                   46854               18421         28433
# 5   2014                   45998               17889         28109
# 6   2015                   44294               17482         26812
# 7   2016                   41863               16465         25398
# 8   2017                   35410               13255         22155
# 9   2018                   34300               13067         21233
# 10  2019                   37266               14619         22647
#
#     Selling, general and administrative expenses  Other operating charges  \
# 0                                          11358                      313
# 1                                          13158                      819
# 2                                          17422                      732
# 3                                          17738                      447
# 4                                          17310                      895
# 5                                          17218                     1183
# 6                                          16427                     1657
# 7                                          15262                     1510
# 8                                          12654                     1902
# 9                                          11002                     1079
# 10                                         12103                      458
#
#     Operating Income  Interest income  Interest expense  \
# 0               8231              249               355
# 1               8449              317               733
# 2              10173              483               417
# 3              10779              471               397
# 4              10228              534               463
# 5               9708              594               483
# 6               8728              613               856
# 7               8626              642               733
# 8               7599              677               841
# 9               9152              689               950
# 10             10086              563               946
#
#     Equity income (loss) — net  Income Before Income Taxes  Income taxes  \
# 0                          781                        8946          2040
# 1                         1025                       14243          2384
# 2                          690                       11458          2812
# 3                          819                       11809          2723
# 4                          602                       11477          2851
# 5                          769                        9325          2201
# 6                          489                        9605          2239
# 7                          835                        8136          1586
# 8                         1071                        6742          5560
# 9                         1008                        8225          1749
# 10                        1049                       10786          1801
#
#     Consolidated Net Income  \
# 0                      6906
# 1                     11859
# 2                      8646
# 3                      9086
# 4                      8626
# 5                      7124
# 6                      7366
# 7                      6550
# 8                      1283
# 9                      6476
# 10                     8985
#
#     Less: Net income attributable to noncontrolling interests  \
# 0                                                  82
# 1                                                  50
# 2                                                  62
# 3                                                  67
# 4                                                  42
# 5                                                  26
# 6                                                  15
# 7                                                  23
# 8                                                  35
# 9                                                  42
# 10                                                 65
#
#     Net Income Attributable to Shareowners of The Coca-Cola Company  \
# 0                                                6824
# 1                                               11809
# 2                                                8584
# 3                                                9019
# 4                                                8584
# 5                                                7098
# 6                                                7351
# 7                                                6527
# 8                                                1248
# 9                                                6434
# 10                                               8920
#
#     Diluted Net Income Per Share 2,3  Average Shares Outstanding Diluted
# 0                                  3                                2329
# 1                                  5                                2333
# 2                                  2                                4646
# 3                                  2                                4584
# 4                                  2                                4509
# 5                                  2                                4450
# 6                                  2                                4405
# 7                                  1                                4367
# 8                                  0                                4324
# 9                                  2                                4299
# 10                                 2                                4314

# %%
df.info
# Out:
# <bound method DataFrame.info of     YEAR  Net Operating Revenues  Cost of goods sold  Gross Profit  \
# 0   2009                   30990               11088         19902
# 1   2010                   35119               12693         22426
# 2   2011                   46542               18215         28327
# 3   2012                   48017               19053         28964
# 4   2013                   46854               18421         28433
# 5   2014                   45998               17889         28109
# 6   2015                   44294               17482         26812
# 7   2016                   41863               16465         25398
# 8   2017                   35410               13255         22155
# 9   2018                   34300               13067         21233
# 10  2019                   37266               14619         22647
#
#     Selling, general and administrative expenses  Other operating charges  \
# 0                                          11358                      313
# 1                                          13158                      819
# 2                                          17422                      732
# 3                                          17738                      447
# 4                                          17310                      895
# 5                                          17218                     1183
# 6                                          16427                     1657
# 7                                          15262                     1510
# 8                                          12654                     1902
# 9                                          11002                     1079
# 10                                         12103                      458
#
#     Operating Income  Interest income  Interest expense  \
# 0               8231              249               355
# 1               8449              317               733
# 2              10173              483               417
# 3              10779              471               397
# 4              10228              534               463
# 5               9708              594               483
# 6               8728              613               856
# 7               8626              642               733
# 8               7599              677               841
# 9               9152              689               950
# 10             10086              563               946
#
#     Equity income (loss) — net  Income Before Income Taxes  Income taxes  \
# 0                          781                        8946          2040
# 1                         1025                       14243          2384
# 2                          690                       11458          2812
# 3                          819                       11809          2723
# 4                          602                       11477          2851
# 5                          769                        9325          2201
# 6                          489                        9605          2239
# 7                          835                        8136          1586
# 8                         1071                        6742          5560
# 9                         1008                        8225          1749
# 10                        1049                       10786          1801
#
#     Consolidated Net Income  \
# 0                      6906
# 1                     11859
# 2                      8646
# 3                      9086
# 4                      8626
# 5                      7124
# 6                      7366
# 7                      6550
# 8                      1283
# 9                      6476
# 10                     8985
#
#     Less: Net income attributable to noncontrolling interests  \
# 0                                                  82
# 1                                                  50
# 2                                                  62
# 3                                                  67
# 4                                                  42
# 5                                                  26
# 6                                                  15
# 7                                                  23
# 8                                                  35
# 9                                                  42
# 10                                                 65
#
#     Net Income Attributable to Shareowners of The Coca-Cola Company  \
# 0                                                6824
# 1                                               11809
# 2                                                8584
# 3                                                9019
# 4                                                8584
# 5                                                7098
# 6                                                7351
# 7                                                6527
# 8                                                1248
# 9                                                6434
# 10                                               8920
#
#     Diluted Net Income Per Share 2,3  Average Shares Outstanding Diluted
# 0                                  3                                2329
# 1                                  5                                2333
# 2                                  2                                4646
# 3                                  2                                4584
# 4                                  2                                4509
# 5                                  2                                4450
# 6                                  2                                4405
# 7                                  1                                4367
# 8                                  0                                4324
# 9                                  2                                4299
# 10                                 2                                4314  >

# %%
df.shape
# Out:
# (11, 18)

# %%
plt.figure(figsize = (10,5))
plt.subplot(1,2,1)
sns.boxplot(y=df['Net Operating Revenues'])



plt.subplot(1,2, 2)
sns.boxplot(y=df['Cost of goods sold'])
plt.show()

# %%
df['Net Operating Revenues'].describe()
# Out:
# count       11.000000
# mean     40604.818182
# std       6115.111116
# min      30990.000000
# 25%      35264.500000
# 50%      41863.000000
# 75%      46270.000000
# max      48017.000000
# Name: Net Operating Revenues, dtype: float64

# %%
plt.bar(df['YEAR'], df['Gross Profit'])
# Out:
# <BarContainer object of 11 artists>
